# %% [markdown]
# # Игра "Крестики-нолики"

# %%
from tic_tac_toe import start

start()
# Out:
#   | 0 1 2
# __|_______
# 0 | - - -
# 1 | - - -
# 2 | - - -
#   | 0 1 2
# __|_______
# 0 | X - -
# 1 | - - -
# 2 | - - -
#   | 0 1 2
# __|_______
# 0 | X - -
# 1 | - - -
# 2 | - - O
#   | 0 1 2
# __|_______
# 0 | X X -
# 1 | - - -
# 2 | - - O
#   | 0 1 2
# __|_______
# 0 | X X O
# 1 | - - -
# 2 | - - O
#   | 0 1 2
# __|_______
# 0 | X X O
# 1 | - - X
# 2 | - - O
#   | 0 1 2
# __|_______
# 0 | X X O
# 1 | - - X
# 2 | - O O
# Клетка занята.
#   | 0 1 2
# __|_______
# 0 | X X O
# 1 | - - X
# 2 | X O O
#   | 0 1 2
# __|_______
# 0 | X X O
# 1 | O - X
# 2 | X O O
#   | 0 1 2
# __|_______
# 0 | X X O
# 1 | O X X
# 2 | X O O
# Ничья!

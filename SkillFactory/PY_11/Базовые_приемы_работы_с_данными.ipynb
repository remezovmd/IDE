# %%
import pandas as pd

melb_data = pd.read_csv('data/melb_data.csv', sep=',')
melb_df = melb_data.copy()
melb_df.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# 4  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# 0        Yarra   -37.7996    144.9984  Northern Metropolitan         4019.0
# 1        Yarra   -37.8079    144.9934  Northern Metropolitan         4019.0
# 2        Yarra   -37.8093    144.9944  Northern Metropolitan         4019.0
# 3        Yarra   -37.7969    144.9969  Northern Metropolitan         4019.0
# 4        Yarra   -37.8072    144.9941  Northern Metropolitan         4019.0
#
#           Coordinates
# 0  -37.7996, 144.9984
# 1  -37.8079, 144.9934
# 2  -37.8093, 144.9944
# 3  -37.7969, 144.9969
# 4  -37.8072, 144.9941
#
# [5 rows x 23 columns]

# %%
melb_df = melb_df.drop(['index', 'Coordinates'], axis=1)
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5      3067  ...       1.0  1.0     202.0         126.0
# 1  4/02/2016       2.5      3067  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5      3067  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5      3067  ...       2.0  1.0      94.0         126.0
# 4  4/06/2016       2.5      3067  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0     1970.0        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3     1970.0        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
total_rooms = melb_df['Rooms'] + melb_df['Bedroom'] + melb_df['Bathroom']
melb_df['MeanRoomsArea'] = melb_df['BuildingArea'] / total_rooms
display(melb_df)
# Out:
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  ...  Landsize  BuildingArea  YearBuilt  \
# 0        Biggin   3/12/2016       2.5  ...     202.0         126.0     1970.0
# 1        Biggin   4/02/2016       2.5  ...     156.0          79.0     1900.0
# 2        Biggin   4/03/2017       2.5  ...     134.0         150.0     1900.0
# 3        Biggin   4/03/2017       2.5  ...      94.0         126.0     1970.0
# 4        Nelson   4/06/2016       2.5  ...     120.0         142.0     2014.0
# ...         ...         ...       ...  ...       ...           ...        ...
# 13575     Barry  26/08/2017      16.7  ...     652.0         126.0     1981.0
# 13576  Williams  26/08/2017       6.8  ...     333.0         133.0     1995.0
# 13577     Raine  26/08/2017       6.8  ...     436.0         126.0     1997.0
# 13578   Sweeney  26/08/2017       6.8  ...     866.0         157.0     1920.0
# 13579   Village  26/08/2017       6.3  ...     362.0         112.0     1920.0
#
#        CouncilArea  Lattitude  Longtitude                  Regionname  \
# 0            Yarra  -37.79960   144.99840       Northern Metropolitan
# 1            Yarra  -37.80790   144.99340       Northern Metropolitan
# 2            Yarra  -37.80930   144.99440       Northern Metropolitan
# 3            Yarra  -37.79690   144.99690       Northern Metropolitan
# 4            Yarra  -37.80720   144.99410       Northern Metropolitan
# ...            ...        ...         ...                         ...
# 13575          NaN  -37.90562   145.16761  South-Eastern Metropolitan
# 13576          NaN  -37.85927   144.87904        Western Metropolitan
# 13577          NaN  -37.85274   144.88738        Western Metropolitan
# 13578          NaN  -37.85908   144.89299        Western Metropolitan
# 13579          NaN  -37.81188   144.88449        Western Metropolitan
#
#       Propertycount           Coordinates  MeanRoomsArea
# 0            4019.0    -37.7996, 144.9984      25.200000
# 1            4019.0    -37.8079, 144.9934      15.800000
# 2            4019.0    -37.8093, 144.9944      18.750000
# 3            4019.0    -37.7969, 144.9969      15.750000
# 4            4019.0    -37.8072, 144.9941      17.750000
# ...             ...                   ...            ...
# 13575        7392.0  -37.90562, 145.16761      12.600000
# 13576        6380.0  -37.85927, 144.87904      16.625000
# 13577        6380.0  -37.85274, 144.88738      15.750000
# 13578        6380.0  -37.85908, 144.89299      17.444444
# 13579        6543.0  -37.81188, 144.88449      12.444444
#
# [13580 rows x 24 columns]

# %%
import pandas as pd
def delete_columns(df, col=[]):
    if set(col).issubset(df.columns.tolist()):
        return df.drop(col, axis=1)

customer_df = pd.DataFrame({
            'number': [0, 1, 2, 3, 4],
            'cust_id': [128, 1201, 9832, 4392, 7472],
            'cust_age': [13, 21, 19, 21, 60],
            'cust_sale': [0, 0, 0.2, 0.15, 0.3],
            'cust_year_birth': [2008, 2000, 2002, 2000, 1961],
            'cust_order': [1400, 14142, 900, 1240, 8430]
        })
delete_columns (customer_df, ['number', 'cust_age'])
# Out:
#    cust_id  cust_sale  cust_year_birth  cust_order
# 0      128       0.00             2008        1400
# 1     1201       0.00             2000       14142
# 2     9832       0.20             2002         900
# 3     4392       0.15             2000        1240
# 4     7472       0.30             1961        8430

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'area': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

countries_df['density'] = countries_df['population'] * 1000000 / countries_df['area']
display(countries_df)
countries_df['density'].mean()
# Out:
#      country  population      area     density
# 0     Англия       56.29    133396  421.976671
# 1     Канада       38.05   9984670    3.810842
# 2        США      322.28   9826630   32.796595
# 3     Россия      146.24  17125191    8.539467
# 4    Украина       45.50    603628   75.377550
# 5   Беларусь        9.50    207600   45.761079
# 6  Казахстан       17.04   2724902    6.253436
# np.float64(84.93080566562001)

# %%
def get_weekend(weekday):
    if weekday in [5,6]:
        return 1
    else:
        return 0

melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)
melb_df['WeekdaySale'] = melb_df['Date'].dt.day_of_week
melb_df['Weekend'] = melb_df['WeekdaySale'].apply(get_weekend)
melb_df[melb_df['Weekend'] == 1]['Price'].mean()
# Out:
# np.float64(1081198.6406956792)

# %%
ufo = pd.read_csv('data/ufo.txt', sep=',')
ufo['Time'] = pd.to_datetime(ufo['Time'], dayfirst=False)
diff = ufo[ufo['State'] == 'NV']['Time'].dt.date.diff().mean()
display(diff)
# Out:
# Timedelta('68 days 22:18:13.992932')

# %%
popular_sellers = melb_df['SellerG'].value_counts().nlargest(49).index
melb_df['SellerG'] = melb_df['SellerG'].apply(lambda x: x if x in popular_sellers else 'other')
display(melb_df['SellerG'])
# Out:
# 0          Biggin
# 1          Biggin
# 2          Biggin
# 3          Biggin
# 4          Nelson
#            ...
# 13575       Barry
# 13576    Williams
# 13577       Raine
# 13578     Sweeney
# 13579     Village
# Name: SellerG, Length: 13580, dtype: str

# %%
print(melb_df[melb_df['SellerG'] == 'Nelson']['Price'].min())
print(melb_df[melb_df['SellerG'] == 'other']['Price'].min())
print (melb_df[melb_df['SellerG'] == 'Nelson']['Price'].min() / melb_df[melb_df['SellerG'] == 'other']['Price'].min())
# Out:
# 170000.0
# 131000.0
# 1.297709923664122

# %%
def get_experience(arg):
    months = 0
    str = arg.split(' ')
    if str[-1] in ['месяц', 'месяца', 'месяцев']:
        months += int(str[-2])
        if str[-3] in ['год', 'года', 'лет']:
            months += int(str[-4]) * 12
    elif str[-1] in ['год', 'года', 'лет']:
        months += int(str[-2]) * 12
    return months

test_series_1 = pd.Series([
    'Опыт работы 8 лет 3 месяца',
    'Опыт работы 3 года 5 месяцев',
    'Опыт работы 1 год 9 месяцев',
    'Опыт работы 3 месяца',
    'Опыт работы 6 лет'
])

print(test_series_1.apply(get_experience))
# Out:
# 0    99
# 1    41
# 2    21
# 3     3
# 4    72
# dtype: int64

# %%
melb_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  str
#  2   Address        13580 non-null  str
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  str
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  str
#  7   SellerG        13580 non-null  str
#  8   Date           13580 non-null  str
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
#  17  CouncilArea    12211 non-null  str
#  18  Lattitude      13580 non-null  float64
#  19  Longtitude     13580 non-null  float64
#  20  Regionname     13580 non-null  str
#  21  Propertycount  13580 non-null  float64
#  22  Coordinates    13580 non-null  str
# dtypes: float64(11), int64(3), str(9)
# memory usage: 2.4 MB

# %%
suburbs = melb_df['Suburb'].value_counts().nlargest(119).index
melb_df['Suburb'] = melb_df['Suburb'].apply(lambda x: x if x in suburbs else 'other')
melb_df['Suburb'].astype('category')
melb_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  str
#  2   Address        13580 non-null  str
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  str
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  str
#  7   SellerG        13580 non-null  str
#  8   Date           13580 non-null  str
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
#  17  CouncilArea    12211 non-null  str
#  18  Lattitude      13580 non-null  float64
#  19  Longtitude     13580 non-null  float64
#  20  Regionname     13580 non-null  str
#  21  Propertycount  13580 non-null  float64
#  22  Coordinates    13580 non-null  str
# dtypes: float64(11), int64(3), str(9)
# memory usage: 2.4 MB

# %%
melb_df['Suburb'].nunique()
melb_df['Suburb'] = melb_df['Suburb'].astype('category')

# %%
melb_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  category
#  2   Address        13580 non-null  str
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  str
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  str
#  7   SellerG        13580 non-null  str
#  8   Date           13580 non-null  str
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
#  17  CouncilArea    12211 non-null  str
#  18  Lattitude      13580 non-null  float64
#  19  Longtitude     13580 non-null  float64
#  20  Regionname     13580 non-null  str
#  21  Propertycount  13580 non-null  float64
#  22  Coordinates    13580 non-null  str
# dtypes: category(1), float64(11), int64(3), str(8)
# memory usage: 2.3 MB
